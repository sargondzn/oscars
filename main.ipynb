# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('oscars.csv', sep=None, engine='python')

df.tail(30)
# Out:
#        Ceremony  Year       Class  \
# 12107        98  2025  Production
# 12108        98  2025     Writing
# 12109        98  2025     Writing
# 12110        98  2025     Writing
# 12111        98  2025     Writing
# 12112        98  2025     Writing
# 12113        98  2025     Writing
# 12114        98  2025     Writing
# 12115        98  2025     Writing
# 12116        98  2025     Writing
# 12117        98  2025     Writing
# 12118        98  2025     Special
# 12119        98  2025     Special
# 12120        98  2025     Special
# 12121        98  2025     Special
# 12122        98  2025     SciTech
# 12123        98  2025     SciTech
# 12124        98  2025     SciTech
# 12125        98  2025     SciTech
# 12126        98  2025     SciTech
# 12127        98  2025     SciTech
# 12128        98  2025     SciTech
# 12129        98  2025     SciTech
# 12130        98  2025     SciTech
# 12131        98  2025     SciTech
# 12132        98  2025     SciTech
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12137 entries, 0 to 12136
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ceremony           12137 non-null  int64
#  1   Year               12137 non-null  str
#  2   Class              12137 non-null  str
#  3   CanonicalCategory  12137 non-null  str
#  4   Category           12137 non-null  str
#  5   Film               10857 non-null  str
#  6   FilmId             10856 non-null  str
#  7   Name               10934 non-null  str
#  8   Nominees           11779 non-null  str
#  9   NomineeIds         11252 non-null  str
#  10  Winner             3515 non-null   object
#  11  Detail             3187 non-null   str
#  12  Note               626 non-null    str
#  13  Citation           1201 non-null   str
# dtypes: int64(1), object(1), str(12)
# memory usage: 1.3+ MB
